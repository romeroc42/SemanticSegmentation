# %% [markdown]
# # Semantic Segmentation of Nucleii
#
# * This is an example of semantic segmentaton using the the Data Science Bowl 2018 dataset; cell nucleii images are labeled using image masks.
# * While the competition was looking for instance segmentation (each nucleii labeled seperately), here we tackle the less complex problem of semantic segmentation.
# * Using the TensorFlow/Keras framework, we train a U-Net neural network to classify the areas of the images that are nucleii, essentially classifying each pixel.

# %%
import os
import multiprocessing
import glob
import datetime
import random
import time
import numpy as np
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import load_img, ImageDataGenerator
import PIL
from PIL import Image
from PIL import ImageChops
from PIL import ImageOps
import pandas as pd
from IPython.display import FileLink

# %% [markdown]
# # 1. Setup Constants and Data, Start TensorBoard

# %%
TRAIN_HOME_DIR = "/kaggle/working/stage1_train"
TEST_HOME_DIR = "/kaggle/working/stage1_test"
#TRAIN_HOME_DIR = "/content/dataset/stage1_train"
#TEST_HOME_DIR = "/content/dataset/stage1_test"
MODEL_CHECKPOINT_NAME = "/kaggle/working/nucleii_segmentation.h5"
#MODEL_CHECKPOINT_NAME = "nucleii_segmentation.h5"
TB_LOGDIR = "/kaggle/working/tensorboardlogs"
TRAIN_SPLIT = 0.8
IMG_SIZE = (128, 128)
#IMG_SIZE = (512, 512)
NUM_CLASSES = 2
BATCH_SIZE = 4
EPOCHS = 50
AUGMENTATION_ON = False

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#! mkdir dataset
#! unzip "/content/drive/MyDrive/data mining y sistemas inteligentes/data-science-bowl-2018.zip" -d dataset

# %%
#!unzip '/content/dataset/stage1_train.zip' -d '/content/dataset/stage1_train'
#!unzip '/content/dataset/stage1_test.zip' -d '/content/dataset/stage1_test'

# %%
# Unzip the training data, download and unzip ngrok to run TensorBoard later
# !mkdir -p /kaggle/working/stage1_train && unzip -n -q /kaggle/input/data-science-bowl-2018/stage1_train.zip -d /kaggle/working/stage1_train
# !mkdir -p /kaggle/working/stage1_test  && unzip -n -q /kaggle/input/data-science-bowl-2018/stage1_test.zip -d /kaggle/working/stage1_test
# !wget -Nq https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip; unzip -n -q ngrok-stable-linux-amd64.zip -d /kaggle/working

# %%
## Start Up TensorBoard and ngrok
# Start TensorBoard, `ngrok` opens a tunnel to our Kaggle session to connect to TensorBoard
# A clickable URL appears in the output below

pool = multiprocessing.Pool(processes = 10)
results_of_processes = [pool.apply_async(os.system, args=(cmd, ), callback = None )
                        for cmd in [
                        f"tensorboard --logdir {TB_LOGDIR} --host 0.0.0.0 --port 6006 &",
                        "./ngrok http 6006 &"
                        ]]
time.sleep(2)
# !curl -s http://localhost:4040/api/tunnels | python3 -c "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# https://d01d368959e7.ngrok.io

# %% [markdown]
# # 2. Define Functions

# %%
from keras.models import Model, load_model, save_model
from keras.layers import Input,Dropout,BatchNormalization,Activation,Add
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras import optimizers

import tensorflow as tf

from keras.preprocessing.image import array_to_img, img_to_array, load_img#,save_img

import time

# %%
def generate_combined_mask(home_dir):
    path_list = [d.path for d in os.scandir(home_dir) if d.is_dir()]
    for img_path in tqdm(iterable=path_list, desc="Processing mask files"):
        searchpath = os.path.join(img_path, "masks", "*.png")
        masklist = glob.glob(searchpath)
        firstmask = Image.open(masklist[0], 'r')
        img_w, img_h = firstmask.size
        background_image = Image.new('L', (img_w, img_h), 0)
        for m in masklist:
            background_image = ImageChops.lighter(background_image, Image.open(m))
        new_mask_dir = os.path.join(img_path, "masks2")
        os.makedirs(new_mask_dir, exist_ok=True)
        new_mask_path = os.path.join(new_mask_dir, "newmask.png")
        background_image.save(new_mask_path)
    image_list = [f.path for i in path_list for f in os.scandir(os.path.join(i, "images")) if f.is_file()]
    masks_list = [f.path for i in path_list for f in os.scandir(os.path.join(i, "masks2")) if f.is_file()]
    return image_list, masks_list

# %%
class Nucleii(keras.utils.Sequence):
    # Helper to turn images into Sequence object for TF model
    def __init__(self, batch_size, img_size, input_img_paths, target_img_paths, img_dtype="float32", tgt_dtype="uint8"):
        self.batch_size = batch_size
        self.img_size = img_size
        self.input_img_paths = input_img_paths
        self.target_img_paths = target_img_paths
        self.img_dtype = img_dtype
        self.tgt_dtype = tgt_dtype

    def __len__(self):
        return len(self.target_img_paths) // self.batch_size

    def __getitem__(self, idx):
        # Returns tuple (input, target) correspond to batch #idx.
        i = idx * self.batch_size
        batch_input_img_paths = self.input_img_paths[i : i + self.batch_size]
        batch_target_img_paths = self.target_img_paths[i : i + self.batch_size]
        x = np.zeros((self.batch_size,) + self.img_size + (3,), dtype=self.img_dtype)
        for j, path in enumerate(batch_input_img_paths):
            img = load_img(path, target_size=self.img_size)
            x[j] = img
        y = np.zeros((self.batch_size,) + self.img_size + (1,), dtype=self.tgt_dtype)
        for j, path in enumerate(batch_target_img_paths):
            img = load_img(path, target_size=self.img_size, color_mode="grayscale")
            tgt_array = np.array(img) / 255
            y[j] = np.expand_dims(tgt_array, 2)
        return x, y

# %%
def image_and_mask_generator(image_list, masks_list, generator_args, image_size, batch_size):
    generator_list = []
    seed = 1
    colormode = {0:"rgb", 1:"grayscale"}
    for i, j in enumerate([image_list, masks_list]):
        dtype = ("uint8" if i==1 else None) # for mask dtype
        generator_args["dtype"] = dtype
        datagen = ImageDataGenerator(**generator_args)
        generator = datagen.flow_from_dataframe(
        dataframe=pd.DataFrame(j),
        directory=None,
        x_col=0,
        target_size=image_size,
        color_mode=colormode[i],
        class_mode=None,
        batch_size=batch_size,
        seed=seed)
        generator_list.append(generator)
    return zip(*generator_list)

# %%
#Build the model
#inputs = tf.keras.layers.Input((128, 128, 3))
#s = tf.keras.layers.Lambda(lambda x: x / 255)(inputs)

# %%
# imports for building the network
import tensorflow as tf
from tensorflow import reduce_sum
from tensorflow.keras.backend import pow
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPool2D, UpSampling2D, Concatenate, Add, Flatten
from tensorflow.keras.losses import binary_crossentropy
from sklearn.model_selection import train_test_split

# %%
def bn_act(x, act=True):
    'batch normalization layer with an optinal activation layer'
    x = tf.keras.layers.BatchNormalization()(x)
    if act == True:
        x = tf.keras.layers.Activation('relu')(x)
    return x

# %%
def conv_block(x, filters, kernel_size=3, padding='same', strides=1):
    'convolutional layer which always uses the batch normalization layer'
    conv = bn_act(x)
    conv = Conv2D(filters, kernel_size, padding=padding, strides=strides)(conv)
    return conv

# %%
def stem(x, filters, kernel_size=3, padding='same', strides=1):
    conv = Conv2D(filters, kernel_size, padding=padding, strides=strides)(x)
    conv = conv_block(conv, filters, kernel_size, padding, strides)
    shortcut = Conv2D(filters, kernel_size=1, padding=padding, strides=strides)(x)
    shortcut = bn_act(shortcut, act=False)
    output = Add()([conv, shortcut])
    return output

# %%
def residual_block(x, filters, kernel_size=3, padding='same', strides=1):
    res = conv_block(x, filters, k_size, padding, strides)
    res = conv_block(res, filters, k_size, padding, 1)
    shortcut = Conv2D(filters, kernel_size, padding=padding, strides=strides)(x)
    shortcut = bn_act(shortcut, act=False)
    output = Add()([shortcut, res])
    return output

# %%
def upsample_concat_block(x, xskip):
    u = UpSampling2D((2,2))(x)
    c = Concatenate()([u, xskip])
    return c

# %%
k_size = 3

# %%
def ResUNet(img_h, img_w):
    f = [16, 32, 64, 128, 256]
    
    inputs = Input((img_h, img_w, 3))
    
    ## Encoder
    e0 = inputs
    e1 = stem(e0, f[0])
    e2 = residual_block(e1, f[1], strides=2)
    e3 = residual_block(e2, f[2], strides=2)
    e4 = residual_block(e3, f[3], strides=2)
    e5 = residual_block(e4, f[4], strides=2)
    
    ## Bridge
    b0 = conv_block(e5, f[4], strides=1)
    b1 = conv_block(b0, f[4], strides=1)
    
    ## Decoder
    u1 = upsample_concat_block(b1, e4)
    d1 = residual_block(u1, f[4])
    
    u2 = upsample_concat_block(d1, e3)
    d2 = residual_block(u2, f[3])
    
    u3 = upsample_concat_block(d2, e2)
    d3 = residual_block(u3, f[2])
    
    u4 = upsample_concat_block(d3, e1)
    d4 = residual_block(u4, f[1])
    
    outputs = tf.keras.layers.Conv2D(2, (1, 1), padding="same", activation="sigmoid")(d4)
    model = tf.keras.models.Model(inputs, outputs)
    return model

# %%
def get_model(img_size, num_classes):
    inputs = keras.Input(shape=img_size + (3,))

    ### [First half of the network: downsampling inputs] ###
    # Entry block
    x = layers.Conv2D(16, 3, strides=2, padding="same")(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    # Blocks 1, 2, 3 are identical apart from the feature depth.
    for filters in [32, 64, 128, 256]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(filters, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    ### [Second half of the network: upsampling inputs] ###

    previous_block_activation = x  # Set aside residual

    for filters in [256, 128, 64, 32, 16]:
        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.UpSampling2D(2)(x)

        # Project residual
        residual = layers.UpSampling2D(2)(previous_block_activation)
        residual = layers.Conv2D(filters, 1, padding="same")(residual)
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    # Add a per-pixel classification layer
    outputs = layers.Conv2D(num_classes, 3, activation="sigmoid", padding="same")(x)

    # Define the model
    model = keras.Model(inputs, outputs)
    return model

# %%
# This is a bug fix for the Keras MeanIoU metric 
# From https://stackoverflow.com/questions/61824470/dimensions-mismatch-error-when-using-tf-metrics-meaniou-with-sparsecategorical
class UpdatedMeanIoU(tf.keras.metrics.MeanIoU):
  def __init__(self,
               y_true=None,
               y_pred=None,
               num_classes=None,
               name=None,
               dtype=None):
    super(UpdatedMeanIoU, self).__init__(num_classes = num_classes,name=name, dtype=dtype)

  def update_state(self, y_true, y_pred, sample_weight=None):
    y_pred = tf.math.argmax(y_pred, axis=-1)
    return super().update_state(y_true, y_pred, sample_weight)

# %% [markdown]
# # 3. Prepare Combined Masks
# Create a single combined mask per image so we can do easier semantic segmentation instead of the more difficult instance segmentation. Return a list of image paths and mask paths

# %%
image_list, masks_list = generate_combined_mask(TRAIN_HOME_DIR)
# Out:
# Processing mask files:   0%|          | 0/670 [00:00<?, ?it/s]

# %% [markdown]
# # 4. Create Image Sequence Objects/Generators

# %%
##--> DATA SETUP: Split our image and mask paths into training/validation sets
val_samples = int(len(image_list) * (1 - TRAIN_SPLIT))
random.Random(1337).shuffle(image_list)
random.Random(1337).shuffle(masks_list)
train_image_list = image_list[:-val_samples]
train_masks_list = masks_list[:-val_samples]
val_image_list = image_list[-val_samples:]
val_masks_list = masks_list[-val_samples:]

# NO AUGMENTATION: Instantiate data Sequence objects for each split
train_seq = Nucleii(BATCH_SIZE, IMG_SIZE, train_image_list, train_masks_list)
val_seq = Nucleii(BATCH_SIZE, IMG_SIZE, val_image_list, val_masks_list)

# ADD AUGMENTATION: Create generator objects that can create infinite augmented images from base dataset
train_data_gen_args  =  dict(rescale=1./255,
                        shear_range=0.5,
                        rotation_range=50,
                        zoom_range=0.2,
                        width_shift_range=0.2,
                        height_shift_range=0.2,
                        fill_mode='reflect'
                        )
                          
val_data_gen_args = dict(rescale=1./255,
                        )

train_gen_aug = image_and_mask_generator(train_image_list, train_masks_list, train_data_gen_args, IMG_SIZE, BATCH_SIZE)
val_gen_aug = image_and_mask_generator(val_image_list, val_masks_list, val_data_gen_args, IMG_SIZE, BATCH_SIZE)
# Out:
# Found 537 validated image filenames.
# Found 537 validated image filenames.
# Found 133 validated image filenames.
# Found 133 validated image filenames.

# %% [markdown]
# # 5. Create Model, Begin Training
# * Define callbacks (incl. TensorBoard, Early Stopping)
# * Define metrics (here MeanIoU per image)
# * Compile model, specifying optimizer & loss function
# * Begin training for specified number of epochs

# %%
# Free up RAM in case the model definition cells were run multiple times
keras.backend.clear_session()

# Set up logging directory, callback functions, and metrics (for TensorBoard)
#log_dir = os.path.join(TB_LOGDIR, datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
callbacks = [
    keras.callbacks.ModelCheckpoint(MODEL_CHECKPOINT_NAME, save_best_only=True),
    #keras.callbacks.TensorBoard(log_dir="logs"),
    tf.keras.callbacks.EarlyStopping(monitor="val_loss", verbose=1, patience=100)
    #keras.callbacks.TensorBoard(log_dir="logs")
    
]
metrics = [
    UpdatedMeanIoU(num_classes=NUM_CLASSES), # bug fix for tf.keras.metrics.MeanIoU, see above
]

# Set up model layers with get_model(), choose optimizer and loss function in compile step
#model = get_model(IMG_SIZE, NUM_CLASSES)

model=ResUNet(128, 128)


#model=get_model_UNet(IMG_SIZE,NUM_CLASSES)
#model=deeplabv3_plus(num_classes=2)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 128, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 128, 128, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 16) 64          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 16) 2320        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 16) 64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 128, 128, 16) 0           conv2d_1[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 16) 64          add[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 128, 16) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 32)   4640        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 32)   4640        add[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 32)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 32)   128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 32)   9248        activation_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 64, 32)   0           batch_normalization_4[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 32)   128         add_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 32)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   18496       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 64)   18496       add_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 64)   36928       activation_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 64)   0           batch_normalization_7[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 64)   256         add_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 128)  73856       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  73856       add_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 128)  147584      activation_6[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 128)  0           batch_normalization_10[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 128)  512         add_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 128)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 256)    295168      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 256)    1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 256)    295168      add_3[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 8, 8, 256)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 256)    1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 256)    590080      activation_8[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 8, 8, 256)    0           batch_normalization_13[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 256)    1024        add_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 8, 8, 256)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 256)    590080      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 256)    1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 256)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 256)    590080      activation_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 16, 16, 256)  0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 384)  0           up_sampling2d[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 16, 16, 384)  1536        concatenate[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 384)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 256)  884992      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 16, 16, 256)  1024        conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 16, 16, 256)  884992      concatenate[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 256)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 16, 16, 256)  1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 256)  590080      activation_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 256)  0           batch_normalization_18[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 256)  0           add_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 320)  0           up_sampling2d_1[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 32, 32, 320)  1280        concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 32, 32, 320)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 32, 32, 128)  368768      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 32, 32, 128)  512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 32, 128)  368768      concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 32, 32, 128)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 32, 32, 128)  512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 32, 32, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 32, 32, 128)  0           batch_normalization_21[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 128)  0           add_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 160)  0           up_sampling2d_2[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 64, 64, 160)  640         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 64, 64, 160)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, 64, 64)   92224       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 64, 64, 64)   256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 64, 64, 64)   92224       concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 64, 64, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 64, 64, 64)   256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 64, 64, 64)   36928       activation_16[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 64, 64, 64)   0           batch_normalization_24[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 64) 0           add_7[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 80) 0           up_sampling2d_3[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 128, 128, 80) 320         concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 128, 128, 80) 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 128, 128, 32) 23072       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 128, 128, 32) 128         conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 128, 128, 32) 23072       concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 128, 128, 32) 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 128, 128, 32) 128         conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 128, 128, 32) 9248        activation_18[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 128, 128, 32) 0           batch_normalization_27[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 128, 128, 2)  66          add_8[0][0]
# ==================================================================================================
# Total params: 6,287,762
# Trainable params: 6,280,466
# Non-trainable params: 7,296
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=metrics)

# Train the model, doing validation at the end of each epoch
if(AUGMENTATION_ON):
    # WITH AUGMENTATION
    print(f"Beginning training for {EPOCHS} epochs, batch size: {BATCH_SIZE}, augmentation: {AUGMENTATION_ON}")
    model.fit(train_gen_aug, steps_per_epoch=1500//BATCH_SIZE, epochs=EPOCHS, validation_data=val_seq, callbacks=callbacks)
else:
    # WITHOUT AUGMENTATION
    print(f"Beginning training for {EPOCHS} epochs, batch size: {BATCH_SIZE}, augmentation: {AUGMENTATION_ON}")
    history=model.fit(train_seq, epochs=EPOCHS, validation_data=val_seq, callbacks=callbacks)
# Out:
# Beginning training for 50 epochs, batch size: 4, augmentation: False
# Epoch 1/50
# 134/134 [==============================] - 249s 2s/step - loss: 0.3373 - updated_mean_io_u: 0.6246 - val_loss: 2.7086 - val_updated_mean_io_u: 0.6892
# Epoch 2/50
# 134/134 [==============================] - 238s 2s/step - loss: 0.1213 - updated_mean_io_u: 0.8295 - val_loss: 0.9249 - val_updated_mean_io_u: 0.7304
# Epoch 3/50
# 134/134 [==============================] - 239s 2s/step - loss: 0.1158 - updated_mean_io_u: 0.8455 - val_loss: 2.6173 - val_updated_mean_io_u: 0.7248
# Epoch 4/50
# 134/134 [==============================] - 237s 2s/step - loss: 0.0912 - updated_mean_io_u: 0.8717 - val_loss: 0.1182 - val_updated_mean_io_u: 0.8489
# Epoch 5/50
# 134/134 [==============================] - 234s 2s/step - loss: 0.0909 - updated_mean_io_u: 0.8768 - val_loss: 0.1086 - val_updated_mean_io_u: 0.8499
# Epoch 6/50
# 134/134 [==============================] - 232s 2s/step - loss: 0.0964 - updated_mean_io_u: 0.8727 - val_loss: 1.9675 - val_updated_mean_io_u: 0.5860
# Epoch 7/50
# 134/134 [==============================] - 233s 2s/step - loss: 0.0957 - updated_mean_io_u: 0.8617 - val_loss: 0.3514 - val_updated_mean_io_u: 0.7926
# Epoch 8/50
# 134/134 [==============================] - 246s 2s/step - loss: 0.0838 - updated_mean_io_u: 0.8839 - val_loss: 0.2109 - val_updated_mean_io_u: 0.7244
# Epoch 9/50
# 134/134 [==============================] - 234s 2s/step - loss: 0.0761 - updated_mean_io_u: 0.8936 - val_loss: 0.1783 - val_updated_mean_io_u: 0.7626
# Epoch 10/50
# 134/134 [==============================] - 235s 2s/step - loss: 0.0719 - updated_mean_io_u: 0.8975 - val_loss: 0.1279 - val_updated_mean_io_u: 0.8196
# Epoch 11/50
# 134/134 [==============================] - 247s 2s/step - loss: 0.0733 - updated_mean_io_u: 0.8907 - val_loss: 0.1055 - val_updated_mean_io_u: 0.8550
# Epoch 12/50
# 134/134 [==============================] - 232s 2s/step - loss: 0.0695 - updated_mean_io_u: 0.8965 - val_loss: 0.1231 - val_updated_mean_io_u: 0.8530
# Epoch 13/50
# 134/134 [==============================] - 244s 2s/step - loss: 0.0758 - updated_mean_io_u: 0.8883 - val_loss: 0.0970 - val_updated_mean_io_u: 0.8765
# Epoch 14/50
# 134/134 [==============================] - 236s 2s/step - loss: 0.0702 - updated_mean_io_u: 0.8970 - val_loss: 0.3471 - val_updated_mean_io_u: 0.8041
# Epoch 15/50
# 134/134 [==============================] - 234s 2s/step - loss: 0.0687 - updated_mean_io_u: 0.8924 - val_loss: 0.2011 - val_updated_mean_io_u: 0.7771
# Epoch 16/50
# 134/134 [==============================] - 244s 2s/step - loss: 0.0780 - updated_mean_io_u: 0.8879 - val_loss: 0.2439 - val_updated_mean_io_u: 0.7853
# Epoch 17/50
# 134/134 [==============================] - 234s 2s/step - loss: 0.0660 - updated_mean_io_u: 0.8979 - val_loss: 0.1681 - val_updated_mean_io_u: 0.7537
# Epoch 18/50
# 134/134 [==============================] - 238s 2s/step - loss: 0.0644 - updated_mean_io_u: 0.9002 - val_loss: 0.1379 - val_updated_mean_io_u: 0.7764
# Epoch 19/50
# 134/134 [==============================] - 244s 2s/step - loss: 0.0618 - updated_mean_io_u: 0.9075 - val_loss: 0.0889 - val_updated_mean_io_u: 0.8858
# Epoch 20/50
# 134/134 [==============================] - 232s 2s/step - loss: 0.0629 - updated_mean_io_u: 0.9039 - val_loss: 0.0825 - val_updated_mean_io_u: 0.8895
# Epoch 21/50
# 134/134 [==============================] - 244s 2s/step - loss: 0.0685 - updated_mean_io_u: 0.8971 - val_loss: 0.1277 - val_updated_mean_io_u: 0.8431
# Epoch 22/50
# 134/134 [==============================] - 233s 2s/step - loss: 0.0598 - updated_mean_io_u: 0.9083 - val_loss: 0.1639 - val_updated_mean_io_u: 0.8654
# Epoch 23/50
# 134/134 [==============================] - 233s 2s/step - loss: 0.0665 - updated_mean_io_u: 0.9027 - val_loss: 0.0957 - val_updated_mean_io_u: 0.8720
# Epoch 24/50
# 134/134 [==============================] - 245s 2s/step - loss: 0.0579 - updated_mean_io_u: 0.9090 - val_loss: 0.0957 - val_updated_mean_io_u: 0.8686
# Epoch 25/50
# 134/134 [==============================] - 233s 2s/step - loss: 0.0687 - updated_mean_io_u: 0.9003 - val_loss: 0.1025 - val_updated_mean_io_u: 0.8577
# Epoch 26/50
# 134/134 [==============================] - 235s 2s/step - loss: 0.0628 - updated_mean_io_u: 0.9029 - val_loss: 0.1911 - val_updated_mean_io_u: 0.7387
# Epoch 27/50
# 134/134 [==============================] - 233s 2s/step - loss: 0.0788 - updated_mean_io_u: 0.8835 - val_loss: 1.8983 - val_updated_mean_io_u: 0.7863
# Epoch 28/50
# 134/134 [==============================] - 232s 2s/step - loss: 0.0751 - updated_mean_io_u: 0.8899 - val_loss: 0.0891 - val_updated_mean_io_u: 0.8868
# Epoch 29/50
# 134/134 [==============================] - 236s 2s/step - loss: 0.0606 - updated_mean_io_u: 0.9046 - val_loss: 0.0885 - val_updated_mean_io_u: 0.8860
# Epoch 30/50
# 134/134 [==============================] - 233s 2s/step - loss: 0.0590 - updated_mean_io_u: 0.9090 - val_loss: 0.0870 - val_updated_mean_io_u: 0.8930
# Epoch 31/50
# 134/134 [==============================] - 237s 2s/step - loss: 0.0591 - updated_mean_io_u: 0.9082 - val_loss: 0.0974 - val_updated_mean_io_u: 0.8848
# Epoch 32/50
# 134/134 [==============================] - 233s 2s/step - loss: 0.0601 - updated_mean_io_u: 0.9073 - val_loss: 0.1000 - val_updated_mean_io_u: 0.8757
# Epoch 33/50
# 134/134 [==============================] - 247s 2s/step - loss: 0.0582 - updated_mean_io_u: 0.9122 - val_loss: 0.0798 - val_updated_mean_io_u: 0.8945
# Epoch 34/50
# 134/134 [==============================] - 234s 2s/step - loss: 0.0548 - updated_mean_io_u: 0.9133 - val_loss: 0.0830 - val_updated_mean_io_u: 0.8994
# Epoch 35/50
# 134/134 [==============================] - 232s 2s/step - loss: 0.0551 - updated_mean_io_u: 0.9123 - val_loss: 0.1236 - val_updated_mean_io_u: 0.8567
# Epoch 36/50
# 134/134 [==============================] - 243s 2s/step - loss: 0.0578 - updated_mean_io_u: 0.9107 - val_loss: 0.0821 - val_updated_mean_io_u: 0.8998
# Epoch 37/50
# 134/134 [==============================] - 235s 2s/step - loss: 0.0598 - updated_mean_io_u: 0.9110 - val_loss: 0.0730 - val_updated_mean_io_u: 0.8995
# Epoch 38/50
# 134/134 [==============================] - 243s 2s/step - loss: 0.0518 - updated_mean_io_u: 0.9126 - val_loss: 0.0772 - val_updated_mean_io_u: 0.8942
# Epoch 39/50
# 134/134 [==============================] - 234s 2s/step - loss: 0.0569 - updated_mean_io_u: 0.9106 - val_loss: 0.1222 - val_updated_mean_io_u: 0.7897
# Epoch 40/50
# 134/134 [==============================] - 232s 2s/step - loss: 0.0569 - updated_mean_io_u: 0.9121 - val_loss: 0.1099 - val_updated_mean_io_u: 0.8220
# Epoch 41/50
# 134/134 [==============================] - 240s 2s/step - loss: 0.0500 - updated_mean_io_u: 0.9186 - val_loss: 0.0907 - val_updated_mean_io_u: 0.8870
# Epoch 42/50
# 134/134 [==============================] - 237s 2s/step - loss: 0.0502 - updated_mean_io_u: 0.9201 - val_loss: 0.1022 - val_updated_mean_io_u: 0.8565
# Epoch 43/50
# 134/134 [==============================] - 234s 2s/step - loss: 0.0509 - updated_mean_io_u: 0.9161 - val_loss: 0.1731 - val_updated_mean_io_u: 0.7784
# Epoch 44/50
# 134/134 [==============================] - 234s 2s/step - loss: 0.0535 - updated_mean_io_u: 0.9165 - val_loss: 0.0920 - val_updated_mean_io_u: 0.8723
# Epoch 45/50
# 134/134 [==============================] - 229s 2s/step - loss: 0.0604 - updated_mean_io_u: 0.9100 - val_loss: 0.0984 - val_updated_mean_io_u: 0.8613
# Epoch 46/50
# 134/134 [==============================] - 236s 2s/step - loss: 0.0677 - updated_mean_io_u: 0.8996 - val_loss: 0.6287 - val_updated_mean_io_u: 0.6213
# Epoch 47/50
# 134/134 [==============================] - 228s 2s/step - loss: 0.0657 - updated_mean_io_u: 0.9036 - val_loss: 0.0908 - val_updated_mean_io_u: 0.8916
# Epoch 48/50
# 134/134 [==============================] - 229s 2s/step - loss: 0.0619 - updated_mean_io_u: 0.9057 - val_loss: 0.1178 - val_updated_mean_io_u: 0.8433
# Epoch 49/50
# 134/134 [==============================] - 237s 2s/step - loss: 0.0583 - updated_mean_io_u: 0.9091 - val_loss: 0.0888 - val_updated_mean_io_u: 0.8987
# Epoch 50/50
# 134/134 [==============================] - 229s 2s/step - loss: 0.0564 - updated_mean_io_u: 0.9130 - val_loss: 0.0849 - val_updated_mean_io_u: 0.8908

# %%
IoU = history.history['updated_mean_io_u']
IoU_val = history.history['val_updated_mean_io_u']
epochs_range = range(EPOCHS)
print(epochs_range)
plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, IoU, label='Training IoU')
plt.plot(epochs_range, IoU_val, label='Validation Training IoU')
plt.legend(loc='lower right')
plt.title('Training and Validation IoU')
plt.draw()
# Out:
# range(0, 50)

# %% [markdown]
# # 6. Predict and Validate Output
# Now that our model is trained, let's predict against some sample data and compare the ground truth mask with our predicted mask.

# %%
val_preds = model.predict(val_seq)

# %%
# Randomly select four images from validation data
# Display input image, input mask, and predicted mask
def plot_images(image_list, mask_list, predictions, sample_size):
    i = np.random.randint(0, len(image_list)-1, size=sample_size)
    f, axarr = plt.subplots(sample_size//2, 6, figsize=(24,int(sample_size*2)))
    axarr = axarr.flatten()
    _ = [a.set_axis_off() for a in axarr.ravel()]
    for x in range(sample_size):
        axarr[3*x].imshow(load_img(image_list[i[x]]))
        axarr[3*x].set_title("Original Image")
        axarr[3*x+1].imshow(load_img(mask_list[i[x]]), cmap="gray")
        axarr[3*x+1].set_title("Ground Truth Mask")
        pred_mask = np.argmax(predictions[i[x]], axis=-1)
        pred_mask = np.expand_dims(pred_mask, axis=-1)
        pred_img = PIL.ImageOps.autocontrast(keras.preprocessing.image.array_to_img(pred_mask))
        axarr[3*x+2].imshow(pred_img, cmap="gray")
        axarr[3*x+2].set_title("Predicted Mask")

VAL_IMG_SAMPLE = 6
plot_images(val_image_list, val_masks_list, val_preds, VAL_IMG_SAMPLE)

# %% [markdown]
# DeepLab v3 +

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np

from keras.models import Model
from keras import layers
from keras.layers import Input
from keras.layers import Activation
from keras.layers import Concatenate
from keras.layers import Add
from keras.layers import Dropout
from keras.layers import BatchNormalization
from keras.layers import Conv2D
from keras.layers import DepthwiseConv2D
from keras.layers import ZeroPadding2D
from keras.layers import AveragePooling2D
#from keras.engine import Layer
#from keras.engine import InputSpec
from keras.engine.topology import get_source_inputs
from keras import backend as K
from keras.applications import imagenet_utils
from keras.utils import conv_utils
from keras.utils.data_utils import get_file

# %%
# Free up RAM in case the model definition cells were run multiple times
keras.backend.clear_session()

# Set up logging directory, callback functions, and metrics (for TensorBoard)
#log_dir = os.path.join(TB_LOGDIR, datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
MODEL_CHECKPOINT_NAME2="nucleii_segmentation2.h5"
callbacks = [
    keras.callbacks.ModelCheckpoint(MODEL_CHECKPOINT_NAME2, save_best_only=True),
    #keras.callbacks.TensorBoard(log_dir="logs"),
    tf.keras.callbacks.EarlyStopping(monitor="val_loss", verbose=1, patience=7)
    #keras.callbacks.TensorBoard(log_dir="logs")
    
]
metrics = [
    UpdatedMeanIoU(num_classes=NUM_CLASSES), # bug fix for tf.keras.metrics.MeanIoU, see above
]

# Set up model layers with get_model(), choose optimizer and loss function in compile step
#model = get_model(IMG_SIZE, NUM_CLASSES)
#model=get_model_UNet(IMG_SIZE,NUM_CLASSES)
model=deeplabv3_plus(num_classes=2)
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-7128f2d39c7e> in <module>
#      19 #model = get_model(IMG_SIZE, NUM_CLASSES)
#      20 #model=get_model_UNet(IMG_SIZE,NUM_CLASSES)
# ---> 21 model=deeplabv3_plus(num_classes=2)
#      22 model.summary()
#
# NameError: name 'deeplabv3_plus' is not defined

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=metrics)

# Train the model, doing validation at the end of each epoch
if(AUGMENTATION_ON):
    # WITH AUGMENTATION
    print(f"Beginning training for {EPOCHS} epochs, batch size: {BATCH_SIZE}, augmentation: {AUGMENTATION_ON}")
    model.fit(train_gen_aug, steps_per_epoch=1500//BATCH_SIZE, epochs=EPOCHS, validation_data=val_seq, callbacks=callbacks)
else:
    # WITHOUT AUGMENTATION
    print(f"Beginning training for {EPOCHS} epochs, batch size: {BATCH_SIZE}, augmentation: {AUGMENTATION_ON}")
    history=model.fit(train_seq, epochs=EPOCHS, validation_data=val_seq, callbacks=callbacks)

# %%
IoU = history.history['updated_mean_io_u']
IoU_val = history.history['val_updated_mean_io_u']
epochs_range = range(EPOCHS)
print(epochs_range)
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, IoU, label='Training IoU')
plt.plot(epochs_range, IoU_val, label='Validation Training IoU')
plt.legend(loc='upper right')
plt.title('Training and Validation IoU')
plt.draw()

# %%
val_preds = model.predict(val_seq)

# %%
# Randomly select four images from validation data
# Display input image, input mask, and predicted mask
def plot_images(image_list, mask_list, predictions, sample_size):
    i = np.random.randint(0, len(image_list)-1, size=sample_size)
    f, axarr = plt.subplots(sample_size//2, 6, figsize=(24,int(sample_size*2)))
    axarr = axarr.flatten()
    _ = [a.set_axis_off() for a in axarr.ravel()]
    for x in range(sample_size):
        axarr[3*x].imshow(load_img(image_list[i[x]]))
        axarr[3*x].set_title("Original Image")
        axarr[3*x+1].imshow(load_img(mask_list[i[x]]), cmap="gray")
        axarr[3*x+1].set_title("Ground Truth Mask")
        pred_mask = np.argmax(predictions[i[x]], axis=-1)
        pred_mask = np.expand_dims(pred_mask, axis=-1)
        pred_img = PIL.ImageOps.autocontrast(keras.preprocessing.image.array_to_img(pred_mask))
        axarr[3*x+2].imshow(pred_img, cmap="gray")
        axarr[3*x+2].set_title("Predicted Mask")

VAL_IMG_SAMPLE = 6
plot_images(val_image_list, val_masks_list, val_preds, VAL_IMG_SAMPLE)
